# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
data = pd.read_csv('mor_3036.csv')
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)
n_components = 600
pca = PCA(n_components=n_components)
data_pca = pca.fit_transform(data_scaled)
data_pca_df = pd.DataFrame(data_pca, columns=[f'PC{i}' for i in range(1, n_components + 1)])
explained_variance = pca.explained_variance_ratio_
cumulative_variance = explained_variance.cumsum()
print("Explained Variance Ratios:\n", explained_variance)
print("Cumulative Explained Variance:\n", cumulative_variance)
data_pca_df.to_csv('mor_3036_reduced.csv', index=False)

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
data = pd.read_csv('morg_3036.csv')
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)
n_components = 400
pca = PCA(n_components=n_components)
data_pca = pca.fit_transform(data_scaled)
data_pca_df = pd.DataFrame(data_pca, columns=data.columns[:n_components])
explained_variance = pca.explained_variance_ratio_
cumulative_variance = explained_variance.cumsum()
print("Explained Variance Ratios:\n", explained_variance)
print("Cumulative Explained Variance:\n", cumulative_variance)
data_pca_df.to_csv('morg_3036_reduced.csv', index=False)
# Out:
# Explained Variance Ratios:
#  [0.0117817  0.00990417 0.00840172 0.00736255 0.00688243 0.00619177
#  0.00575865 0.00573727 0.0054641  0.0052554  0.00514959 0.00508511
#  0.00487539 0.00479544 0.00475172 0.00451976 0.00446061 0.00442008
#  0.00435054 0.00421388 0.00417679 0.00410969 0.0040627  0.00403153
#  0.00395951 0.00393242 0.00391401 0.00386703 0.00381616 0.00378364
#  0.00374443 0.00372289 0.00367539 0.00366114 0.00363067 0.00360657
#  0.00357914 0.00354425 0.00351584 0.00349486 0.00346342 0.00344617
#  0.00341801 0.00338296 0.00334613 0.0033337  0.00330121 0.00328409
#  0.00325776 0.00323512 0.00322736 0.00320689 0.00319372 0.00317644
#  0.00312877 0.00312053 0.00310832 0.00306923 0.00306546 0.00304807
#  0.00303207 0.00300945 0.00299585 0.00298823 0.00297733 0.00293684
#  0.00292377 0.00291792 0.00290817 0.0028927  0.00288564 0.00288197
#  0.00284663 0.00282397 0.00280698 0.00279111 0.00277779 0.00277111
#  0.00274818 0.00274668 0.00271174 0.00270908 0.00269465 0.0026823
# ...

# %%
data_pca_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -1.320748 -2.991242  0.710843  1.482190 -1.081096 -0.488795  0.230486
# 1 -1.320748 -2.991242  0.710843  1.482190 -1.081096 -0.488795  0.230486
# 2 -1.320748 -2.991242  0.710843  1.482190 -1.081096 -0.488795  0.230486
# 3 -0.044657 -3.045062 -1.160130 -0.098183 -0.999758 -3.404309  2.448965
# 4  7.369459 -0.403676 -2.667551  1.969379  0.447673 -0.726126 -1.311837
#
#           7         8         9  ...       390       391       392       393  \
# 0  2.090824 -2.450902  0.767004  ...  0.334152 -0.572766  0.230423 -0.076844
# 1  2.090824 -2.450902  0.767004  ...  0.334152 -0.572766  0.230423 -0.076844
# 2  2.090824 -2.450902  0.767004  ...  0.334152 -0.572766  0.230423 -0.076844
# 3  3.573045  2.948838 -2.066418  ...  0.579882 -1.190108  0.840845 -1.572312
# 4 -4.224151 -0.237779  2.932908  ... -0.726588 -0.101603  0.161813 -0.379173
#
#         394       395       396       397       398       399
# ...

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
data = pd.read_csv('path_3036.csv')
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)
n_components = 400
pca = PCA(n_components=n_components)
data_pca = pca.fit_transform(data_scaled)
data_pca_df = pd.DataFrame(data_pca, columns=data.columns[:n_components])

explained_variance = pca.explained_variance_ratio_
cumulative_variance = explained_variance.cumsum()
print("Explained Variance Ratios:\n", explained_variance)
print("Cumulative Explained Variance:\n", cumulative_variance)
data_pca_df.to_csv('path_3036_reduced.csv', index=False)
# Out:
# Explained Variance Ratios:
#  [0.10217881 0.05624273 0.03839968 0.03253569 0.02776203 0.02263169
#  0.01970189 0.01962168 0.0159207  0.01514122 0.01337241 0.01312507
#  0.01201816 0.01129298 0.01033945 0.00984643 0.00955476 0.00916747
#  0.00866459 0.00834983 0.00825393 0.00789933 0.00776195 0.00721648
#  0.00694297 0.00668999 0.00652498 0.00627187 0.00595738 0.00585883
#  0.00574128 0.00558343 0.00530197 0.00522967 0.00503136 0.0049131
#  0.0048283  0.0047217  0.00460499 0.00452972 0.00444022 0.00438817
#  0.0042528  0.00414803 0.00411789 0.00403034 0.00398399 0.0039006
#  0.00388914 0.00376691 0.00370377 0.00359642 0.00354239 0.00350634
#  0.00344028 0.00335334 0.00334    0.00331249 0.00330408 0.00320536
#  0.00313909 0.00306143 0.00304327 0.0029945  0.00294379 0.00290119
#  0.00288253 0.00284476 0.00280552 0.00279183 0.00269212 0.00267829
#  0.00264027 0.00260737 0.00258524 0.00255471 0.00251246 0.00247264
#  0.00245174 0.00242607 0.00237983 0.0023595  0.00234626 0.00231769
# ...

# %%
data_pca_df.head()
# Out:
#           0          1         2         3         4         5         6  \
# 0  2.182636 -10.396101 -2.414890  4.411537  9.746406 -6.192686  0.899006
# 1  2.182636 -10.396101 -2.414890  4.411537  9.746406 -6.192686  0.899006
# 2  2.182636 -10.396101 -2.414890  4.411537  9.746406 -6.192686  0.899006
# 3  6.905482  -0.123025 -3.859774  8.027338  7.035921 -3.527805 -1.021880
# 4 -8.377933   3.189171 -4.447280  7.216834 -6.959525 -1.800068 -0.300964
#
#           7         8         9  ...       390       391       392       393  \
# 0 -0.918488 -0.650650 -1.962811  ...  0.001915 -0.305348 -0.445290  0.550588
# 1 -0.918488 -0.650650 -1.962811  ...  0.001915 -0.305348 -0.445290  0.550588
# 2 -0.918488 -0.650650 -1.962811  ...  0.001915 -0.305348 -0.445290  0.550588
# 3 -0.490311 -2.847647  1.430347  ...  0.396931 -0.987970 -0.554923  1.097305
# 4 -0.253869  3.347625  3.134099  ...  0.262720 -0.437583  0.363672 -0.413725
#
#         394       395       396       397       398       399
# ...

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
data = pd.read_csv('mor_3036.csv')
imputer = SimpleImputer(strategy='mean')
data_imputed = imputer.fit_transform(data)
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data_imputed)

n_components = 600
pca = PCA(n_components=n_components)
data_pca = pca.fit_transform(data_scaled)
data_pca_df = pd.DataFrame(data_scaled, columns=data.columns[:1512])
data_pca_df.to_csv('mor_3036_a.csv', index=False)

# %%
data_pca_df.head()
# Out:
#          ABC      ABCGG      nAcid     nBase   SpAbs_A   SpMax_A  SpDiam_A  \
# 0 -13.667010  16.312193   6.994569  3.081949  0.158277 -3.078238 -1.513964
# 1 -13.667010  16.312193   6.994569  3.081949  0.158277 -3.078238 -1.513964
# 2 -13.667010  16.312193   6.994569  3.081949  0.158277 -3.078238 -1.513964
# 3  39.518368  -6.132076   1.131515  4.291451  0.041876  0.588057  2.118136
# 4  14.717175  -5.910723  12.895570 -0.009040 -3.685942  3.827118 -0.406732
#
#      SpAD_A   SpMAD_A   LogEE_A  ...    GATS4i    GATS5i    GATS6i    GATS7i  \
# 0  5.533443  9.059370  8.428870  ...  0.008556 -0.008723 -0.052065  0.003694
# 1  5.533443  9.059370  8.428870  ...  0.008556 -0.008723 -0.052065  0.003694
# 2  5.533443  9.059370  8.428870  ...  0.008556 -0.008723 -0.052065  0.003694
# 3 -4.644766  0.442991  4.448453  ... -0.018078  0.055673 -0.031324 -0.000355
# 4 -0.172485  4.507235 -5.997264  ... -0.011135 -0.008685 -0.005962 -0.013124
#
# ...

# %%
data_pca_df.shape
# Out:
# (3018, 600)

# %%
import pandas as pd
df=pd.read_csv("ir_3036.csv")
df_n=df.dropna()
df_n.shape
# Out:
# (3018, 802)

# %%
df_n.to_csv("ir_final.csv")
